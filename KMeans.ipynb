# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data={'Age':[20,21,34,23,45,24,25,31,29,57],
      'Salary':[23000,12000,34000,25000,32000,76000,65000,54000,74000,89000]
     }
df=pd.DataFrame(data)
X=df[['Age','Salary']]
model=KMeans(n_clusters=3,random_state=42)
model.fit(X)
df['cluster']=model.labels_
print(df)
# Out:
#    Age  Salary  cluster
# 0   20   23000        0
# 1   21   12000        2
# 2   34   34000        0
# 3   23   25000        0
# 4   45   32000        0
# 5   24   76000        1
# 6   25   65000        1
# 7   31   54000        1
# 8   29   74000        1
# 9   57   89000        1

# %%
plt.figure(figsize=(8,6))
plt.scatter(
    df['Age'],
    df['Salary'],
    c=df['cluster'])
plt.scatter(
    model.cluster_centers_[:,0],
    model.cluster_centers_[:,1],
    marker='X',
    s=200)
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
wcss=[]
for i in range(1,11):
    model=KMeans(n_clusters=i,random_state=42)
    model.fit(X)
    wcss.append(model.inertia_)
plt.plot(range(1,11),wcss,marker='o')
plt.xlabel('no of cluster')
plt.ylabel('wcss')
plt.title('elbow method')
plt.show()
